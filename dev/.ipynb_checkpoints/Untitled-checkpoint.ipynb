# %%
from pathways import Pathways

# %%
p = Pathways(datapackage="sample/datapackage.json")

# %%
planetary_boundaries = {
    "Climate change": {"value": 6.81E+12, "method": "EF v3.1 - climate change - global warming potential (GWP100)", "unit": "kg CO2 eq"},
    "Ozone depletion": {"value": 5.39E+08, "method": "EF v3.1 - ozone depletion - ozone depletion potential (ODP)", "unit": "kg CFC-11 eq"},
    "Marine eutrophication": {"value": 2.01E+11, "method": "EF v3.1 - eutrophication: marine - fraction of nutrients reaching marine end compartment (N)", "unit": "kg N eq"},
    "Freshwater eutrophication": {"value": 5.81E+09, "method": "EF v3.1 - eutrophication: freshwater - fraction of nutrients reaching freshwater end compartment (P)", "unit": "kg P eq"},
    "Terrestrial eutrophication": {"value": 6.13E+12, "method": "EF v3.1 - eutrophication: terrestrial - accumulated exceedance (AE)", "unit": "molc N eq"},
    "Acidification": {"value": 1.00E+12, "method": "EF v3.1 - acidification - accumulated exceedance (AE)", "unit": "molc H+ eq"},
    "Water use": {"value": 1.82E+14, "method": "EF v3.1 - water use - user deprivation potential (deprivation-weighted water consumption)", "unit": "m3 world eq"},
    "Particulate matter": {"value": 5.16E+05, "method": "EF v3.1 - particulate matter formation - impact on human health", "unit": "Disease incidence"},
    "Photochemical ozone formation": {"value": 4.07E+11, "method": "EF v3.1 - photochemical oxidant formation: human health - tropospheric ozone concentration increase", "unit": "kg NMVOC eq"},
    "Human toxicity, cancer": {"value": 9.62E+05, "method": "EF v3.1 - human toxicity: carcinogenic - comparative toxic unit for human (CTUh)", "unit": "CTUh"},
    "Human toxicity, non-cancer": {"value": 4.10E+06, "method": "EF v3.1 - human toxicity: non-carcinogenic - comparative toxic unit for human (CTUh)", "unit": "CTUh"},
    "Ecotoxicity, freshwater": {"value": 1.31E+14, "method": "EF v3.1 - ecotoxicity: freshwater - comparative toxic unit for ecosystems (CTUe)", "unit": "CTUe"},
    "Ionising radiation, human health": {"value": 5.27E+14, "method": "EF v3.1 - ionising radiation: human health - human exposure efficiency relative to u235", "unit": "kBq U235 eq"},
    "Resource use, fossils": {"value": 2.24E+14, "method": "EF v3.1 - energy resources: non-renewable - abiotic depletion potential (ADP): fossil fuels", "unit": "MJ"},
    "Resource use, mineral and metals": {"value": 2.19E+08, "method": "EF v3.1 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)", "unit": "kg Sb eq"},
}

# %%
p.calculate(
    methods=[
        x["method"] for x in planetary_boundaries.values()
    ],
    #years=[
    #    2080,
        #2090, 2100
    #],
    regions=["World"],
    scenarios=[
        "SSP2-Base",
        #"SSP2-RCP26",
    ]
)

# %%
arr = p.display_results()

# %%
arr.sel(impact_category="EF v3.1 - climate change - global warming potential (GWP100)").sum()
# Out:
# <xarray.DataArray 'value' ()>
# array(2.92231597e+12)
# Coordinates:
#     impact_category  <U60 'EF v3.1 - climate change - global warming potentia...

# %%
arr.sel(impact_category="EF v3.1 - climate change - global warming potential (GWP100)").sum()
# Out:
# <xarray.DataArray 'value' ()>
# array(3.05895655e+12)
# Coordinates:
#     impact_category  <U60 'EF v3.1 - climate change - global warming potentia...

# %%
arr_human_health = arr.copy()
arr_human_health.loc[dict(impact_category="EF v3.1 - human toxicity: carcinogenic - comparative toxic unit for human (CTUh)")] *= 1.15E+01
arr_human_health.loc[dict(impact_category="EF v3.1 - human toxicity: non-carcinogenic - comparative toxic unit for human (CTUh)")] *= 2.70E+00
arr_human_health.loc[dict(impact_category="EF v3.1 - particulate matter formation - impact on human health")] *= 2.14E+01
arr_human_health.loc[dict(impact_category="EF v3.1 - ionising radiation: human health - human exposure efficiency relative to u235")] *= 2.10E-08

# %%
arr_human_health.coords["impact_category"].values
# Out:
# array(['EF v3.1 - acidification - accumulated exceedance (AE)',
#        'EF v3.1 - climate change - global warming potential (GWP100)',
#        'EF v3.1 - ecotoxicity: freshwater - comparative toxic unit for ecosystems (CTUe)',
#        'EF v3.1 - energy resources: non-renewable - abiotic depletion potential (ADP): fossil fuels',
#        'EF v3.1 - eutrophication: freshwater - fraction of nutrients reaching freshwater end compartment (P)',
#        'EF v3.1 - eutrophication: marine - fraction of nutrients reaching marine end compartment (N)',
#        'EF v3.1 - eutrophication: terrestrial - accumulated exceedance (AE)',
#        'EF v3.1 - human toxicity: carcinogenic - comparative toxic unit for human (CTUh)',
#        'EF v3.1 - human toxicity: non-carcinogenic - comparative toxic unit for human (CTUh)',
#        'EF v3.1 - ionising radiation: human health - human exposure efficiency relative to u235',
#        'EF v3.1 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)',
#        'EF v3.1 - ozone depletion - ozone depletion potential (ODP)',
#        'EF v3.1 - particulate matter formation - impact on human health',
#        'EF v3.1 - photochemical oxidant formation: human health - tropospheric ozone concentration increase',
#        'EF v3.1 - water use - user deprivation potential (deprivation-weighted water consumption)'],
#       dtype=object)

# %%
import seaborn as sns
df = p.scenarios.sel(region="World", model="image",).to_dataframe("val").unstack()["val"]
df_grouped = df.groupby(['variable', 'pathway']).sum()
df_non_zero = df_grouped.loc[(df_grouped!=0).any(axis=1)]
df_non_zero.reset_index(inplace=True)
df_final = df_non_zero.groupby('variable').filter(lambda x: len(x) > 1)
df_final
# Out:
# year              variable     pathway       2005       2010       2015  \
# 0              Biomass CHP   SSP2-Base   0.275926   0.510579   0.619839
# 1              Biomass CHP  SSP2-RCP26   0.275926   0.510579   0.619839
# 5               Biomass ST   SSP2-Base   0.424332   0.743357   1.114045
# 6               Biomass ST  SSP2-RCP26   0.424332   0.743357   1.114045
# 7                 Coal CHP   SSP2-Base   1.663613   2.027687   1.687761
# 8                 Coal CHP  SSP2-RCP26   1.663613   2.027687   1.687761
# 10               Coal IGCC   SSP2-Base   0.000000   0.000000   0.000000
# 11               Coal IGCC  SSP2-RCP26   0.000000   0.000000   0.000000
# 13                 Coal PC   SSP2-Base  24.165411  28.806119  32.096840
# 14                 Coal PC  SSP2-RCP26  24.165411  28.806119  32.096840
# 15                  Gas CC   SSP2-Base   9.343029  12.924590  15.528200
# 16                  Gas CC  SSP2-RCP26   9.343029  12.924590  15.528200
# 18                 Gas CHP   SSP2-Base   3.060559   4.068842   3.514320
# 19                 Gas CHP  SSP2-RCP26   3.060559   4.068842   3.514320
# 21                  Gas OC   SSP2-Base   0.094374   0.130551   0.156850
# 22                  Gas OC  SSP2-RCP26   0.094374   0.130551   0.156850
# 23              Geothermal   SSP2-Base   0.207317   0.241592   0.276714
# 44     5.356492   6.822834   6.522784   7.459610   7.686989   7.775711
# 45    21.020209  29.419909  35.072049  40.568160  49.796628  64.532070
# 46    39.731470  48.313020  46.640951  54.648508  62.484009  67.325690

# %%
import seaborn as sns
df = p.scenarios.sel(region="World", model="image",).to_dataframe("val").unstack()["val"]
df_grouped = df.groupby(['variable', 'pathway']).sum()
df_non_zero = df_grouped.loc[(df_grouped!=0).any(axis=1)]
df_non_zero.reset_index(inplace=True)
df_final = df_non_zero.groupby('variable').filter(lambda x: len(x) > 1)
df_final = df_final.groupby(["pathway", "variable"]).sum().T

import matplotlib.pyplot as plt
df_final["SSP2-Base"].plot(kind="area", stacked=True,
       #color=color_palette, 
       figsize=(7, 5))
plt.ylim(0, 400)
plt.legend(ncols=2)
plt.title("Global electricity production mix")
plt.ylabel("Exajoules")
plt.savefig("electricity_mix_Base.png")

# %%
import seaborn as sns
df = p.scenarios.sel(region="World", model="image",).to_dataframe("val").unstack()["val"]
df_grouped = df.groupby(['variable', 'pathway']).sum()
df_non_zero = df_grouped.loc[(df_grouped!=0).any(axis=1)]
df_non_zero.reset_index(inplace=True)
df_final = df_non_zero.groupby('variable').filter(lambda x: len(x) > 1)
df_final = df_final.groupby(["pathway", "variable"]).sum().T

import matplotlib.pyplot as plt
df_final["SSP2-RCP26"].plot(kind="area", stacked=True,
       #color=color_palette, 
       figsize=(7, 5))
plt.ylim(0, 400)
plt.legend(ncols=2)
plt.title("Global electricity production mix")
plt.ylabel("Exajoules")
plt.savefig("electricity_mix_RCP26.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns



# Fill NaNs with 0 (optional, depending on how you want to handle NaNs)
df = arr.sel(model="image", scenario="SSP2-RCP26").to_dataframe("val").unstack()["val"].reset_index()
df_base = arr.sel(model="image", scenario="SSP2-Base").to_dataframe("val").unstack()["val"].reset_index()

d_titles = {
    'Cumulative Energy Demand (CED) - total - energy content (HHV)': "Cumulative Energy Demand",
    'IPCC 2021 - climate change - GWP 100a, incl. H': "climate change, 100y",
    'EN15804 - inventory indicators ISO21930 - use of net fresh water': "use of net fresh water",
    'selected LCI results, additional - air - particulates': "air - particulates",
    'selected LCI results - resource - land occupation': "land occupation",
    'EF v3.1 - climate change - global warming potential (GWP100)': "climate change",
    'EF v3.1 - ozone depletion - ozone depletion potential (ODP)': "ozone depletion",
    'EF v3.1 - photochemical oxidant formation: human health - tropospheric ozone concentration increase': "Photochemical ozone formation",
    'EF v3.1 - eutrophication: freshwater - fraction of nutrients reaching freshwater end compartment (P)': "freshwater eutrophication",
    'EF v3.1 - eutrophication: marine - fraction of nutrients reaching marine end compartment (N)': "marine eutrophication",
    'EF v3.1 - acidification - accumulated exceedance (AE)': "ocean acidification",
    'EF v3.1 - eutrophication: terrestrial - accumulated exceedance (AE)': "terrestrial eutrophication",
    'selected LCI results - resource - land occupation': "land use",
    'EN15804 - inventory indicators ISO21930 - use of net fresh water': "use of freshwater"
}

d_titles.update(
  {v["method"]: k for k, v in planetary_boundaries.items()}
)

d_units = {
    'Cumulative Energy Demand (CED) - total - energy content (HHV)': "MJ primary",
    'IPCC 2021 - climate change - GWP 100a, incl. H': "kg CO$_2$-eq.",
    'EN15804 - inventory indicators ISO21930 - use of net fresh water': "m$^3$",
    'selected LCI results, additional - air - particulates': "kg",
    'selected LCI results - resource - land occupation': "m$^2$-year",
}
d_units.update(
    {v["method"]: v["unit"] for k, v in planetary_boundaries.items()}
)

# Define your categories
impact_categories = df['impact_category'].unique()


fig, axs = plt.subplots(4, 3, figsize=(15, 17))
axs = axs.ravel()  # flatten the array to iterate over it

skip_cats = [
    "EF v3.1 - human toxicity: carcinogenic - comparative toxic unit for human (CTUh)",
    "EF v3.1 - human toxicity: non-carcinogenic - comparative toxic unit for human (CTUh)",
    "EF v3.1 - particulate matter formation - impact on human health",
    "EF v3.1 - ionising radiation: human health - human exposure efficiency relative to u235",
]

impact_categories = [i for i in impact_categories if i not in skip_cats]

for ax, impact_category in zip(axs, impact_categories):
    if impact_category in skip_cats:
        continue
    # Filter dataframe for each impact_category
    df_filtered = df[df['impact_category'] == impact_category]

    # Create a pivot table where index is 'year', columns are 'act_category', and values are 'WEU'
    pivot = df_filtered.pivot_table(values='World', index='year', columns='act_category', fill_value=0)

    # Create the stackplot
    ax.stackplot(pivot.index, pivot.T, labels=pivot.columns)
    
    df_base_filtered = df_base[df_base['impact_category'] == impact_category]
    pivot_base = df_base_filtered.pivot_table(values='World', index='year', columns='act_category', fill_value=0)
    ax.plot(pivot_base.index, pivot_base.T.sum(0), linewidth=3, c="orange", linestyle="dotted", label="SSP2-Base")
    

   
    
    ax.set_title(d_titles[impact_category])
    ax.set_ylabel(d_units.get(impact_category))
    
    ax.axhline(planetary_boundaries[d_titles[impact_category]]["value"], 0, 6, linewidth=5, color = 'r', linestyle=":", label="Planetary boundary")
    
    # Set the title for each subplot
    ax.legend(fontsize=7, loc="upper center")
    

# Fill NaNs with 0 (optional, depending on how you want to handle NaNs)
df = arr_human_health.sel(model="image", scenario="SSP2-RCP26", impact_category=skip_cats).sum(dim="act_category").to_dataframe("val").unstack()["val"].reset_index()    
# Create a pivot table where index is 'year', columns are 'act_category', and values are 'WEU'
pivot = df.pivot_table(values='World', index='year', columns='impact_category', fill_value=0)
pivot = pivot.rename(columns={
    'EF v3.1 - human toxicity: carcinogenic - comparative toxic unit for human (CTUh)': 'Human toxicity, cancer',
    'EF v3.1 - human toxicity: non-carcinogenic - comparative toxic unit for human (CTUh)': 'Human toxicity, non-cancer',
    'EF v3.1 - ionising radiation: human health - human exposure efficiency relative to u235': 'Ionising radiation',
    'EF v3.1 - particulate matter formation - impact on human health': 'Particulate matter'
}
)

# Create the stackplot
axs[11].stackplot(pivot.index, pivot.T.cumsum(1), labels=pivot.columns)

axs[11].set_title("Disability-adjusted Life Years (cumul.)")
axs[11].set_ylabel("DALY (cumulative)")

df = arr_human_health.sel(model="image", scenario="SSP2-Base", impact_category=skip_cats).sum(dim="act_category").to_dataframe("val").unstack()["val"].reset_index()    
# Create a pivot table where index is 'year', columns are 'act_category', and values are 'WEU'
pivot = df.pivot_table(values='World', index='year', columns='impact_category', fill_value=0)
pivot = pivot.rename(columns={
    'EF v3.1 - human toxicity: carcinogenic - comparative toxic unit for human (CTUh)': 'Human toxicity, cancer',
    'EF v3.1 - human toxicity: non-carcinogenic - comparative toxic unit for human (CTUh)': 'Human toxicity, non-cancer',
    'EF v3.1 - ionising radiation: human health - human exposure efficiency relative to u235': 'Ionising radiation',
    'EF v3.1 - particulate matter formation - impact on human health': 'Particulate matter'
})
axs[11].plot(pivot.index, pivot.T.cumsum(1).sum(0), linewidth=3, c="orange", linestyle="dotted", label="SSP2-Base")

axs[11].legend(fontsize=7, loc="upper center")

# Automatically adjust the subplot layout
plt.tight_layout()

# Display the figure
plt.savefig("results_RCP26.png")
plt.show()

# %%
pivot.T.cumsum(1).sum(0)
# Out:
# year
# 2005    9.806417e+06
# 2006    1.987687e+07
# 2007    3.021137e+07
# 2008    4.080990e+07
# 2009    5.167247e+07
#             ...
# 2096    1.717980e+09
# 2097    1.743051e+09
# 2098    1.768429e+09
# 2099    1.794114e+09
# 2100    1.820105e+09
# Length: 96, dtype: float64

# %%
import brightway2 as bw
bw.projects.set_current("ei39")

# %%
res = []

for method in bw.methods:
    m = bw.Method(method)
    res.append({"unit": m.metadata["unit"], "name": m.name, "exchanges": [{"name": bw.get_activity(x)["name"], "categories": list(bw.get_activity(x)["categories"]), "amount": y} for x, y in m.load()]})
    #for cf in m.load():
    #    r
    #    print(cf)

# %%
import json
with open('data.json', 'w') as f:
    json.dump(res, f)

# %%
bw2io.__file__
# Out:
# '/opt/homebrew/Caskroom/miniforge/base/envs/ab/lib/python3.9/site-packages/bw2io/__init__.py'

# %%
from scipy.interpolate import interpn

c = interpn(
    ([2005, 2015, 2025, 2045, 2100], range(0, 35073), range(0, 35073)),
    np.nan_to_num(p.lca_A.sel(model="image", scenario="SSP2-Base").values),
    (2008, range(0, 35073), range(0, 35073))
)

# %%
import numpy as np
np.nan_to_num(c).sum()
# Out:
# 0.0

# %%
import pandas as pd
df = pd.read_excel("sample/scenario_data/scenario_data2.xlsx")
#df.head()
df.columns = ["model", "pathway", "region", "variables", "unit", 2005, 2010, 2015, 2020, 2025, 2030, 2035, 2040, 2045, 2050, 2060, 2070, 2080, 2090,2100]
#df.head()
df = df.melt(
       id_vars=["model", "pathway", "region", "variables", "unit",]
)

# %%
df.columns = ["model", "pathway", "region", "variable", "unit", "year", "value"]

# %%
df.to_csv("scenario_data2.csv", index=False)

# %%
df.to_csv?
# Out:
# Object `df.to_csv` not found.

# %%
df["unit"].unique()
# Out:
# array(['GW', 'Mt CO2/yr', '-', 'GJ/tNH3', 'MJ/Tkm', 'kg CO2/GJ-prim',
#        'Gg BCyr', 'Mt BC/yr', 'Tg CH4/yr', 'Mt CH4/yr', 'MtCO2/yr',
#        'Tg C/yr', 'Mt CO/yr', 'Mt CO2-equiv/yr', 'Tg N/yr', 'kt N2O/yr',
#        'Mt NH3/yr', 'Tg Nyr', 'Mt NO2/yr', 'Mt NOx/yr', 'Gg OC/yr',
#        'Mt OC/yr', 'Tg S/yr', 'Mt SO2/yr', 'Tg VOCyr', 'Mt VOC/yr',
#        'Mt/year', '°C days', 'GJ/cap', 'GJ/m2', 'GJ', 'kJ/m2/HDD',
#        'bn tkm/yr', 'bn pkm/yr', 'tN/yr', 'tP2O5/yr', 'EJ/yr', 'PJ/yr',
#        'billion US$2010/yr OR local currency', 'million ha', 'Ha/GJ-Prim',
#        'years', 'million', 'US$2010/GJ', 'Mtonne/yr', 'Mt/yr', '°C',
#        'billion US$2010/yr'], dtype=object)
