# %%
from premise import *
from datapackage import Package
import bw2io as bw
from polyviz import sankey

# %%
import bw2data
bw2data.projects.set_current("ei310")

# %%
labels_swap={
    "passenger car vehicle": "pass. cars",
    ", passenger car": "",
    r"\(SPS\)": "",
    r"\(sps\)": "",
    "internal ": "",
    ", low-sulfur": "",
    "from neighboring countries": "from Europe",
    "carriers": "",
    "combustion": "combust.",
    "passenger car": "pass. car",
    "proton exchange membrane ": "",
    "battery management system": "BMS",
    "production": "",
    "fuel cell": "FC",
    ", vehicle \(electric powertrain\)": "",
    "1 kWe, ": "",
    "distribution": "distr.",
    "electric ": "elec. ",
    "811": "",
    "Li-ion": "Li",
    "electricity": "elec.",
    " , ": ", "
}

# %%
_, df = sankey(
    activity=[a for a in bw2data.Database("2020") if a["name"] == "market for energy carriers for cars (SPS)"][0],
    method=('ReCiPe 2016 v1.03, midpoint (H)', 'particulate matter formation', 'particulate matter formation potential (PMFP)'),
    level=3,
    amount=1.40562356e+11,
    figsize=(500, 400),
    labels_swap=labels_swap
)
# Out:
# Calculating supply chain score...
# /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.21e+13)
#   warnings.warn(msg, UmfpackWarning)

# %%
df.to_excel("PM 2020.xlsx")

# %%
_, df = sankey(
    activity=[a for a in bw2data.Database("stem 2050") if a["name"] == "market for energy carriers for cars (SPS)"][0],
    method=('ReCiPe 2016 v1.03, midpoint (H)', 'particulate matter formation', 'particulate matter formation potential (PMFP)'),
    #method=('EN15804', 'inventory indicators ISO21930', 'use of net fresh water'),
    level=4,
    amount=4.62017741e+10,
    figsize=(500, 400),
    labels_swap=labels_swap
)
# Out:
# Calculating supply chain score...
# /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.41e+13)
#   warnings.warn(msg, UmfpackWarning)

# %%
df.to_excel("PM 2050.xlsx")

# %%
[m for m in bw2data.methods if "water" in m[2]]
# Out:
# [('CML v4.8 2016 no LT',
#   'ecotoxicity: freshwater no LT',
#   'freshwater aquatic ecotoxicity (FAETP inf) no LT'),
#  ('CML v4.8 2016',
#   'ecotoxicity: freshwater',
#   'freshwater aquatic ecotoxicity (FAETP inf)'),
#  ('Ecological Scarcity 2021 no LT',
#   'emissions to water no LT',
#   'heavy metals into water no LT'),
#  ('Ecological Scarcity 2021 no LT',
#   'emissions to water no LT',
#   'POP into water no LT'),
#  ('Ecological Scarcity 2021 no LT',
#   'emissions to water no LT',
#   'radioactive substances into water no LT'),
#  ('Ecological Scarcity 2021 no LT',
#   'emissions to water no LT',
#   'water pollutants no LT'),
#  ('Ecological Scarcity 2021 no LT',
#   'water use no LT',
#   'water resources, evaporated no LT'),
#  ('Ecological Scarcity 2021', 'emissions to water', 'heavy metals into water'),
#  ('Ecological Scarcity 2021', 'emissions to water', 'POP into water'),
#  ('Ecological Scarcity 2021',
#   'emissions to water',
# ...
